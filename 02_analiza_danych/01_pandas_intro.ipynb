# %% [markdown]
# <a href="https://colab.research.google.com/github/PiKoz360/test_ml/blob/main/02_analiza_danych/01_pandas_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * @author: krakowiakpawel9@gmail.com
# * @site: e-smartdata.org

# %% [markdown]
# ### Pandas
# >Strona biblioteki: [https://pandas.pydata.org/](https://pandas.pydata.org/)
# >Dokumentacja: [https://pandas.pydata.org/pandas-docs/stable/](https://pandas.pydata.org/pandas-docs/stable/)
# >
# >Podstawowa biblioteka do analizy danych w języku Python.
# >
# >Aby zainstalować bibliotekę Pandas użyj polecenia poniżej:
# ```
# pip install pandas
# ```
# ### Spis treści:
# 1. [Podstawowe struktury danych: pd.Series](#a1)
# 2. [Podstawowe struktury danych: pd.DataFrame](#a2)
# 3. [Selekcja kolumn](#a3)

# %%
import pandas as pd
pd.__version__
# Out:
# '2.1.4'

# %% [markdown]
# ### <a name='a1'></a>  Podstawowe struktury danych: pd.Series

# %%
s = pd.Series(data=[3, 2, 4, 6])
s
# Out:
# 0    3
# 1    2
# 2    4
# 3    6
# dtype: int64

# %%
s = pd.Series(data=[3, 2, 4, 6], index=['a', 'b', 'c', 'd'], name='sample')
s
# Out:
# a    3
# b    2
# c    4
# d    6
# Name: sample, dtype: int64

# %%
s = pd.Series(data=[3., 2, 4, 6], index=['a', 'b', 'c', 'd'], name='sample')
s
# Out:
# a    3.0
# b    2.0
# c    4.0
# d    6.0
# Name: sample, dtype: float64

# %% [markdown]
# wstawianie braku wartości za pośrednictwem numpy
# odpowiada za to np.nan

# %%
import numpy as np

s = pd.Series(data=[3., np.nan, 4, 6], index=['a', 'b', 'c', 'd'], name='sample')
s
# Out:
# a    3.0
# b    NaN
# c    4.0
# d    6.0
# Name: sample, dtype: float64

# %%
s = pd.Series(data=[True, False, False])
s
# Out:
# 0     True
# 1    False
# 2    False
# dtype: bool

# %% [markdown]
# indeksowanie z wykorzystaniem daty;
# wymagane żeby podać start wykorzystując po/date.range
# parametr periods odpowiada za ilość dni ile chcemy mieć od tego dnia (podanego jako star)

# %%
s = pd.Series(data=np.arange(10, 20), index=pd.date_range(start='20200101', periods=10))
s
# Out:
# 2020-01-01    10
# 2020-01-02    11
# 2020-01-03    12
# 2020-01-04    13
# 2020-01-05    14
# 2020-01-06    15
# 2020-01-07    16
# 2020-01-08    17
# 2020-01-09    18
# 2020-01-10    19
# Freq: D, dtype: int64

# %% [markdown]
# listowanie listy indeksów

# %%
list(s.index)
# Out:
# [Timestamp('2020-01-01 00:00:00'),
#  Timestamp('2020-01-02 00:00:00'),
#  Timestamp('2020-01-03 00:00:00'),
#  Timestamp('2020-01-04 00:00:00'),
#  Timestamp('2020-01-05 00:00:00'),
#  Timestamp('2020-01-06 00:00:00'),
#  Timestamp('2020-01-07 00:00:00'),
#  Timestamp('2020-01-08 00:00:00'),
#  Timestamp('2020-01-09 00:00:00'),
#  Timestamp('2020-01-10 00:00:00')]

# %%
s.dtypes
# Out:
# dtype('int64')

# %%
s = pd.Series(data=['python', 'java', 'sql'], name='languages')
s
# Out:
# 0    python
# 1      java
# 2       sql
# Name: languages, dtype: object

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
s.values
# Out:
# array(['python', 'java', 'sql'], dtype=object)

# %% [markdown]
# atrybut podaje typ danych
# duże O od Objects

# %%
s.dtypes
# Out:
# dtype('O')

# %%
s.shape
# Out:
# (3,)

# %% [markdown]
# tworzenie obiektu typu series ze słownika

# %%
import numpy as np

price = pd.Series(data={'Apple': 200, 'CD Projekt': 65, 'Amazon': 1900, 'KGHM': np.nan})
price
# Out:
# Apple          200.0
# CD Projekt      65.0
# Amazon        1900.0
# KGHM             NaN
# dtype: float64

# %% [markdown]
# podajemy nazwę obiektu oraz klucz po którym chcemy wyciąć

# %%
price['CD Projekt']
# Out:
# 65.0

# %% [markdown]
# klucz po indeksie

# %%
price[1]
# Out:
# <ipython-input-27-36dbb2ffbeb5>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   price[1]
# 65.0

# %%
price.iloc[1]
# Out:
# 65.0

# %% [markdown]
# funcka 'count' zliczy ile mamy obiekjtów w obiekcie typu series

# %%
price.count()
# Out:
# 3

# %% [markdown]
# funcka potrafi znależć rozkład naszych danych
# sprawdfza ile razy wystąpiła każda z wartości
#
# jeśli uzyjemy parametru: dropna na false dostaniemy też dan ez brakiem 'nan'

# %%
price.value_counts(dropna=False)
# Out:
# 200.0     1
# 65.0      1
# 1900.0    1
# NaN       1
# Name: count, dtype: int64

# %%
price.sum()
# Out:
# 2165.0

# %%
price.min()
# Out:
# 65.0

# %%
price.max()
# Out:
# 1900.0

# %% [markdown]
# odhcylenie standardowe

# %%
price.std()
# Out:
# 1022.6965988666108

# %% [markdown]
# wszystkie funkcje na raz wyświetlone
# pozwala opisać zbiorczo wszystkie statystyki o obiekcie

# %%
price.describe()
# Out:
# count       3.000000
# mean      721.666667
# std      1022.696599
# min        65.000000
# 25%       132.500000
# 50%       200.000000
# 75%      1050.000000
# max      1900.000000
# dtype: float64

# %% [markdown]
# dwie największe - ilość rzeczy decyduje

# %%
price.nlargest(2)
# Out:
# Amazon    1900.0
# Apple      200.0
# dtype: float64

# %%
price.nsmallest(2)
# Out:
# CD Projekt     65.0
# Apple         200.0
# dtype: float64

# %% [markdown]
# zwraca ranking (uporządkowanie) obiektu

# %%
price.rank()
# Out:
# Apple         2.0
# CD Projekt    1.0
# Amazon        3.0
# KGHM          NaN
# dtype: float64

# %% [markdown]
# sortowanie wartości w sposób rosnący

# %%
price.sort_values()
# Out:
# CD Projekt      65.0
# Apple          200.0
# Amazon        1900.0
# KGHM             NaN
# dtype: float64

# %% [markdown]
# sortowanie po wartości z parametrem ascending=False żeby pokazał dane od wartości najwyższej do nqajniższej

# %%
price.sort_values(ascending=False)
# Out:
# Amazon        9310.0
# Apple          980.0
# CD Projekt     318.5
# KGHM             NaN
# dtype: float64

# %% [markdown]
# konwersja obiektu price
# konwersja ceny z wartości w $ na wartość w PLN

# %%
price_pln= price.apply(lambda x: x * 4.9)

# %%
price_pln
# Out:
# Apple          980.0
# CD Projekt     318.5
# Amazon        9310.0
# KGHM             NaN
# dtype: float64

# %%
price_pln.sort_values(ascending=False)
# Out:
# Amazon        9310.0
# Apple          980.0
# CD Projekt     318.5
# KGHM             NaN
# dtype: float64

# %% [markdown]
# ### <a name='a2'></a>  Podstawowe struktury danych: pd.DataFrame

# %%
df = pd.DataFrame(data=[12, 12, 32])
df
# Out:
#     0
# 0  12
# 1  12
# 2  32

# %% [markdown]
# obiekt dataframe z indexem o odpowienich nazwach oraz z definiofaną nazwą kolumn

# %%
df = pd.DataFrame(data=[12, 12, 32], index=['first', 'second', 'third'], columns=['col_1'])
df
# Out:
#         col_1
# first      12
# second     12
# third      32

# %% [markdown]
# indeks automatycznie przypisany
# ramki danych tworzone ze słownika z odpowiednimi litami

# %%
df = pd.DataFrame(data={'WIG20': ['PKN ORLEN', 'PKO BP'],
                        'mWIG40': ['Amica', 'Playway']})
df
# Out:
#        WIG20   mWIG40
# 0  PKN ORLEN    Amica
# 1     PKO BP  Playway

# %% [markdown]
# parametr data przekazany jako zagnieżdząona lista
# indeks jako parametr
# lista nazw kolumn jako aprametr columns
#
# tak tworzymy ramkę danych

# %%
df = pd.DataFrame(data=[[10, 12, 13], [23, 12, 10]], index=['first', 'second'], columns=['col_1', 'col_2', 'col_3'])
df
# Out:
#         col_1  col_2  col_3
# first      10     12     13
# second     23     12     10

# %% [markdown]
# listowanie kolumn

# %%
df.columns
# Out:
# Index(['col_1', 'col_2', 'col_3'], dtype='object')

# %% [markdown]
# listowanie indeksów

# %%
df.index
# Out:
# Index(['first', 'second'], dtype='object')

# %% [markdown]
# zwrot wartości z obiektu dataframe

# %%
df.values
# Out:
# array([[10, 12, 13],
#        [23, 12, 10]])

# %% [markdown]
# zwróci nam informacje na temat obiektu

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, first to second
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   col_1   2 non-null      int64
#  1   col_2   2 non-null      int64
#  2   col_3   2 non-null      int64
# dtypes: int64(3)
# memory usage: 64.0+ bytes

# %%
df.describe()
# Out:
#            col_1  col_2     col_3
# count   2.000000    2.0   2.00000
# mean   16.500000   12.0  11.50000
# std     9.192388    0.0   2.12132
# min    10.000000   12.0  10.00000
# 25%    13.250000   12.0  10.75000
# 50%    16.500000   12.0  11.50000
# 75%    19.750000   12.0  12.25000
# max    23.000000   12.0  13.00000

# %%
df.describe().T
# Out:
#        count  mean       std   min    25%   50%    75%   max
# col_1    2.0  16.5  9.192388  10.0  13.25  16.5  19.75  23.0
# col_2    2.0  12.0  0.000000  12.0  12.00  12.0  12.00  12.0
# col_3    2.0  11.5  2.121320  10.0  10.75  11.5  12.25  13.0

# %% [markdown]
# ### <a name='a3'> </a> Selekcja kolumn

# %%
df
# Out:
#         col_1  col_2  col_3
# first      10     12     13
# second     23     12     10

# %% [markdown]
# nawias kwadratowy jest używany do wycinania
#
# zostanie zwrócona kolumna
# i warto się zastanowić nad typem tej kolumny

# %%
df['col_1']
# Out:
# first     10
# second    23
# Name: col_1, dtype: int64

# %%
type(df['col_1'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# wycięc ie jednej kolumny następuje poprzez podwójną notację nawiasu kwadratowego

# %%
df[['col_1']]
# Out:
#         col_1
# first      10
# second     23

# %%
type(df[['col_1']])
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns = ['a', 'sprzedaz_grudzien', 'c']
df
# Out:
#          a  sprzedaz_grudzien   c
# first   10                 12  13
# second  23                 12  10

# %% [markdown]
# zwrócenie obiektu typu series przy użyciu samej nazwy kolumny
#
# niezawsze praktyczny bo może zawierać np spacje

# %%
df.sprzedaz_grudzien
# Out:
# first     12
# second    12
# Name: sprzedaz_grudzien, dtype: int64

# %% [markdown]
# żeby stworzyć nową kolumnę musimy najpierw wskazać informacje o nazwie kolumny i dopiero wykonać jakieś działania jakie mają być w tej kolumnie
#
# dodawanie dodatkowej kolumny i sumowanie wartości z wybranych kolumn

# %%
df['d'] = df.a + df.c
df
# Out:
#          a  sprzedaz_grudzien   c   d
# first   10                 12  13  23
# second  23                 12  10  33

# %%
df = pd.DataFrame(data=[[10, 12, 13], [23, 12, 10]], index=['first', 'second'], columns=['col_1', 'col_2', 'col_3'])
df
# Out:
#         col_1  col_2  col_3
# first      10     12     13
# second     23     12     10

# %% [markdown]
# wicinanie metodą 'loc'
# wycinanie kolumny

# %%
df.loc['first']
# Out:
# col_1    10
# col_2    12
# col_3    13
# Name: first, dtype: int64

# %% [markdown]
# wycinanie konkretnej wartości poprzez podanie indeksu i kolumny zwróci wartość

# %%
df.loc['first', 'col_2']
# Out:
# 12

# %%
df.loc[:, 'col_2']
# Out:
# first     12
# second    12
# Name: col_2, dtype: int64

# %%
df.iloc[0]
# Out:
# col_1    10
# col_2    12
# col_3    13
# Name: first, dtype: int64

# %%
df.iloc[0, 1]
# Out:
# 12
