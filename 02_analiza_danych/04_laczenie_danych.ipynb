# %% [markdown]
# <a href="https://colab.research.google.com/github/PiKoz360/test_ml/blob/main/02_analiza_danych/04_laczenie_danych.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * @author: krakowiakpawel9@gmail.com
# * @site: e-smartdata.org

# %% [markdown]
# ### Pandas
# Strona biblioteki: [https://pandas.pydata.org/](https://pandas.pydata.org/)
# Dokumentacja: [https://pandas.pydata.org/pandas-docs/stable/](https://pandas.pydata.org/pandas-docs/stable/)
#
# Podstawowa biblioteka do analizy danych w języku Python.
#
# Aby zainstalować bibliotekę Pandas użyj polecenia poniżej:
# ```
# pip install pandas
# ```
# ### Spis treści:
# 1. [Import bibliotek](#a1)
# 2. [Wczytanie danych](#a2)
# 3. [Preprocessing](#a3)
# 4. [Konkatenacja danych](#a4)
# 5. [Metoda append()](#a5)

# %% [markdown]
# ### <a name='a1'></a> Import bibliotek

# %%
import pandas as pd
pd.__version__
# Out:
# '2.1.4'

# %% [markdown]
# ### <a name='a2'></a> Wczytanie danych

# %%
def fetch_financial_data(company='AMZN'):
    """
    This function fetch stock market quotations.
    """
    import pandas_datareader.data as web
    return web.DataReader(name=company, data_source='stooq')

apple = fetch_financial_data('AAPL')
amazon = fetch_financial_data('AMZN')
google = fetch_financial_data('GOOGL')
uber = fetch_financial_data('UBER')

# %%
uber.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1256 entries, 2024-08-05 to 2019-08-08
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1256 non-null   float64
#  1   High    1256 non-null   float64
#  2   Low     1256 non-null   float64
#  3   Close   1256 non-null   float64
#  4   Volume  1256 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 58.9 KB

# %%
apple.head()
# Out:
#               Open    High     Low   Close      Volume
# Date
# 2019-12-10  268.60  270.07  265.86  268.48  22632383.0
# 2019-12-09  270.00  270.80  264.91  266.92  32182645.0
# 2019-12-06  267.48  271.00  267.30  270.71  26547493.0
# 2019-12-05  263.79  265.89  262.73  265.58  18661343.0
# 2019-12-04  261.07  263.31  260.68  261.74  16810388.0

# %% [markdown]
# ### <a name='a3'></a> Preprocessing

# %%
apple.columns = ['apple_' + col.lower() for col in apple.columns]
amazon.columns = ['amazon_' + col.lower() for col in amazon.columns]
google.columns = ['google_' + col.lower() for col in google.columns]
uber.columns = ['uber_' + col.lower() for col in uber.columns]

# %%
apple.head()
# Out:
#             apple_open  apple_high  apple_low  apple_close  apple_volume
# Date
# 2024-08-05      199.09     213.500     196.00       209.27   119548589.0
# 2024-08-02      219.15     225.600     217.71       219.86   105568560.0
# 2024-08-01      224.37     224.480     217.02       218.36    62500996.0
# 2024-07-31      221.44     223.820     220.63       222.08    50036262.0
# 2024-07-30      219.19     220.325     216.12       218.80    41643840.0

# %% [markdown]
# ### <a name='a4'></a> Konkatenacja danych

# %%
df = pd.concat(objs=[apple, amazon, google, uber], axis=1)
df
# Out:
#             apple_open  apple_high  apple_low  apple_close  apple_volume  \
# Date
# 2024-08-05    199.0900    213.5000   196.0000     209.2700  1.195486e+08
# 2024-08-02    219.1500    225.6000   217.7100     219.8600  1.055686e+08
# 2024-08-01    224.3700    224.4800   217.0200     218.3600  6.250100e+07
# 2024-07-31    221.4400    223.8200   220.6300     222.0800  5.003626e+07
# 2024-07-30    219.1900    220.3250   216.1200     218.8000  4.164384e+07
# ...                ...         ...        ...          ...           ...
# 2019-08-14     49.6077     50.4093    49.4691      49.5090  1.496704e+08
# 2019-08-13     49.0873     51.8010    49.0404      51.0293  1.946866e+08
# 2019-08-12     48.7403     49.3396    48.6306      48.9547  9.206861e+07
# 2019-08-09     49.1551     49.5110    48.6626      49.0803  1.008236e+08
# 2019-08-08     48.6994     49.5110    48.5090      49.4870  1.110306e+08
#
#             amazon_open  amazon_high  amazon_low  amazon_close  amazon_volume  \
# Date
# 2024-08-05     154.2100     162.9600    151.6100      161.0200       83149437
# 2024-08-02     166.7500     168.7700    160.5500      167.9000      141448365
# 2024-08-01     189.2850     190.6000    181.8700      184.0700       70435635
# 2024-07-31     185.0500     187.9400    184.4600      186.9800       41667326
# 2024-07-30     184.7200     185.8600    179.3800      181.7100       39508574
# ...                 ...          ...         ...           ...            ...
# 2019-08-14      89.6505      89.7825     87.8610       88.1480       97872980
# 2019-08-13      89.1500      91.5870     89.0000       91.2170       81500420
# 2019-08-12      89.7995      90.0490     88.8500       89.2460       58109960
# 2019-08-09      91.4475      91.5545     90.1110       90.3790       57595400
# 2019-08-08      90.3000      91.7130     89.9055       91.6445       74024840
#
#             google_open  google_high  google_low  google_close  google_volume  \
# Date
# 2024-08-05     155.5000     164.4300    154.9300      159.2500       53630673
# 2024-08-02     166.4400     168.5100    164.6700      166.6600       29130102
# 2024-08-01     170.2500     174.0500    168.8800      170.7600       24531392
# 2024-07-31     173.2400     174.2450    170.0100      171.5400       25729090
# 2024-07-30     170.2400     171.2299    168.4400      170.2900       18959686
# ...                 ...          ...         ...           ...            ...
# 2019-08-14      58.8035      59.1395     58.0535       58.2125       35430020
# 2019-08-13      58.7175      60.2715     58.6500       59.8365       28604800
# 2019-08-12      59.0000      59.2805     58.4360       58.7250       22064860
# 2019-08-09      60.0000      60.2230     59.2445       59.4450       20418900
# 2019-08-08      59.3215      60.3140     58.7000       60.3095       30116960
#
#             uber_open  uber_high  uber_low  uber_close  uber_volume
# Date
# 2024-08-05      55.53    58.6500     54.84       58.48     32063685
# 2024-08-02      59.38    59.5800     56.86       58.99     27654556
# 2024-08-01      64.86    65.0000     60.76       61.02     18967935
# 2024-07-31      63.88    65.1820     63.66       64.47     18209679
# 2024-07-30      64.15    64.7700     62.61       63.09     16506187
# ...               ...        ...       ...         ...          ...
# 2019-08-14      36.00    36.2999     33.36       33.96     24481636
# 2019-08-13      37.00    37.4600     36.12       36.45     19031422
# 2019-08-12      39.84    39.9500     37.00       37.00     20632310
# 2019-08-09      39.56    40.6800     38.71       40.05     35138775
# 2019-08-08      41.98    43.0000     41.25       42.97     29610463
#
# [1256 rows x 20 columns]

# %%
df.describe()
# Out:
#         apple_open   apple_high  ...  uber_close   uber_volume
# count  2502.000000  2502.000000  ...  149.000000  1.490000e+02
# mean    103.047014   103.959041  ...   36.077718  1.768119e+07
# std      56.150446    56.639246  ...    6.164417  2.163312e+07
# min      23.938000    24.363000  ...   25.990000  3.380003e+06
# 25%      57.154000    57.664750  ...   31.080000  7.598828e+06
# 50%      91.883500    92.611500  ...   34.000000  9.746505e+06
# 75%     143.570000   144.795000  ...   42.610000  2.109839e+07
# max     270.000000   271.000000  ...   46.380000  1.863225e+08
#
# [8 rows x 20 columns]

# %%
pd.set_option('display.float_format', lambda x: f'{x:.2f}')

df.describe().T
# Out:
#                 count        mean         std         min         25%  \
# apple_open    1256.00      139.41       42.34       48.70      118.11
# apple_high    1256.00      140.98       42.65       49.34      119.46
# apple_low     1256.00      137.95       42.03       48.51      116.44
# apple_close   1256.00      139.54       42.33       48.95      117.84
# apple_volume  1256.00 96330957.59 53088927.18 24048344.00 60978371.22
# amazon_open   1256.00      138.16       31.74       82.08      108.07
# amazon_high   1256.00      139.84       31.92       83.48      110.54
# amazon_low    1256.00      136.36       31.45       81.30      106.32
# amazon_close  1256.00      138.12       31.66       81.82      107.95
# amazon_volume 1256.00 70482472.51 33196544.75 17626740.00 48660707.00
# google_open   1256.00      110.34       31.86       52.82       85.00
# google_high   1256.00      111.61       32.11       53.35       86.47
# google_low    1256.00      109.17       31.60       50.44       83.26
# google_close  1256.00      110.42       31.86       52.71       85.26
# google_volume 1256.00 33082458.85 14442207.16  9312760.00 23704440.00
# uber_open     1256.00       41.92       14.19       15.96       31.14
# uber_high     1256.00       42.71       14.29       17.80       31.80
# uber_low      1256.00       41.10       14.03       13.71       30.47
# uber_close    1256.00       41.91       14.14       14.82       31.16
# uber_volume   1256.00 25039181.86 17544213.39  5021190.00 15982842.00
#
#                       50%          75%          max
# apple_open         146.39       171.60       236.48
# apple_high         147.94       173.42       237.23
# apple_low          144.66       170.30       233.09
# apple_close        146.53       171.92       234.82
# apple_volume  82289558.28 113500623.33 434708544.96
# amazon_open        143.91       164.85       200.09
# amazon_high        145.90       166.35       201.20
# amazon_low         141.50       162.96       199.04
# amazon_close       144.43       164.70       200.00
# amazon_volume 61961095.50  82642515.00 311345660.00
# google_open        112.32       136.00       190.31
# google_high        113.72       137.16       191.75
# google_low         111.16       134.33       189.03
# google_close       112.41       135.84       191.18
# google_volume 29207814.50  37351235.00 123199220.00
# uber_open           37.92        49.97        81.94
# uber_high           38.60        50.76        82.14
# uber_low            37.08        48.78        80.79
# uber_close          37.78        49.89        81.39
# uber_volume   21016479.50  28990000.75 364261230.00

# %%
df.corr()
# Out:
#                apple_open  apple_high  apple_low  apple_close  apple_volume  \
# apple_open           1.00        1.00       1.00         1.00         -0.56
# apple_high           1.00        1.00       1.00         1.00         -0.55
# apple_low            1.00        1.00       1.00         1.00         -0.57
# apple_close          1.00        1.00       1.00         1.00         -0.56
# apple_volume        -0.56       -0.55      -0.57        -0.56          1.00
# amazon_open          0.52        0.52       0.52         0.52         -0.16
# amazon_high          0.52        0.52       0.52         0.52         -0.16
# amazon_low           0.52        0.52       0.52         0.52         -0.17
# amazon_close         0.52        0.52       0.52         0.52         -0.16
# amazon_volume       -0.36       -0.35      -0.37        -0.36          0.62
# google_open          0.89        0.89       0.89         0.89         -0.53
# google_high          0.89        0.89       0.89         0.89         -0.52
# google_low           0.89        0.89       0.89         0.89         -0.53
# google_close         0.89        0.89       0.89         0.89         -0.53
# google_volume       -0.17       -0.16      -0.17        -0.17          0.47
# uber_open            0.50        0.50       0.51         0.50         -0.32
# uber_high            0.50        0.50       0.51         0.50         -0.32
# uber_low             0.51        0.50       0.51         0.51         -0.33
# uber_close           0.50        0.50       0.51         0.50         -0.32
# uber_volume         -0.04       -0.04      -0.04        -0.04          0.22
#
#                amazon_open  amazon_high  amazon_low  amazon_close  \
# apple_open            0.52         0.52        0.52          0.52
# apple_high            0.52         0.52        0.52          0.52
# apple_low             0.52         0.52        0.52          0.52
# apple_close           0.52         0.52        0.52          0.52
# apple_volume         -0.16        -0.16       -0.17         -0.16
# amazon_open           1.00         1.00        1.00          1.00
# amazon_high           1.00         1.00        1.00          1.00
# amazon_low            1.00         1.00        1.00          1.00
# amazon_close          1.00         1.00        1.00          1.00
# amazon_volume        -0.18        -0.17       -0.20         -0.19
# google_open           0.69         0.69        0.69          0.69
# google_high           0.68         0.68        0.68          0.68
# google_low            0.69         0.69        0.69          0.69
# google_close          0.68         0.68        0.68          0.69
# google_volume        -0.17        -0.16       -0.18         -0.17
# uber_open             0.71         0.71        0.72          0.71
# uber_high             0.71         0.71        0.72          0.71
# uber_low              0.71         0.70        0.72          0.71
# uber_close            0.71         0.70        0.72          0.71
# uber_volume          -0.11        -0.11       -0.11         -0.11
#
#                amazon_volume  google_open  google_high  google_low  \
# apple_open             -0.36         0.89         0.89        0.89
# apple_high             -0.35         0.89         0.89        0.89
# apple_low              -0.37         0.89         0.89        0.89
# apple_close            -0.36         0.89         0.89        0.89
# apple_volume            0.62        -0.53        -0.52       -0.53
# amazon_open            -0.18         0.69         0.68        0.69
# amazon_high            -0.17         0.69         0.68        0.69
# amazon_low             -0.20         0.69         0.68        0.69
# amazon_close           -0.19         0.69         0.68        0.69
# amazon_volume           1.00        -0.40        -0.39       -0.41
# google_open            -0.40         1.00         1.00        1.00
# google_high            -0.39         1.00         1.00        1.00
# google_low             -0.41         1.00         1.00        1.00
# google_close           -0.40         1.00         1.00        1.00
# google_volume           0.56        -0.22        -0.21       -0.23
# uber_open              -0.37         0.63         0.63        0.64
# uber_high              -0.37         0.63         0.63        0.64
# uber_low               -0.38         0.64         0.63        0.64
# uber_close             -0.38         0.63         0.63        0.64
# uber_volume             0.24        -0.06        -0.06       -0.07
#
#                google_close  google_volume  uber_open  uber_high  uber_low  \
# apple_open             0.89          -0.17       0.50       0.50      0.51
# apple_high             0.89          -0.16       0.50       0.50      0.50
# apple_low              0.89          -0.17       0.51       0.51      0.51
# apple_close            0.89          -0.17       0.50       0.50      0.51
# apple_volume          -0.53           0.47      -0.32      -0.32     -0.33
# amazon_open            0.68          -0.17       0.71       0.71      0.71
# amazon_high            0.68          -0.16       0.71       0.71      0.70
# amazon_low             0.68          -0.18       0.72       0.72      0.72
# amazon_close           0.69          -0.17       0.71       0.71      0.71
# amazon_volume         -0.40           0.56      -0.37      -0.37     -0.38
# google_open            1.00          -0.22       0.63       0.63      0.64
# google_high            1.00          -0.21       0.63       0.63      0.63
# google_low             1.00          -0.23       0.64       0.64      0.64
# google_close           1.00          -0.23       0.63       0.63      0.64
# google_volume         -0.23           1.00      -0.20      -0.20     -0.21
# uber_open              0.63          -0.20       1.00       1.00      1.00
# uber_high              0.63          -0.20       1.00       1.00      1.00
# uber_low               0.64          -0.21       1.00       1.00      1.00
# uber_close             0.63          -0.21       1.00       1.00      1.00
# uber_volume           -0.06           0.26      -0.17      -0.16     -0.18
#
#                uber_close  uber_volume
# apple_open           0.50        -0.04
# apple_high           0.50        -0.04
# apple_low            0.51        -0.04
# apple_close          0.50        -0.04
# apple_volume        -0.32         0.22
# amazon_open          0.71        -0.11
# amazon_high          0.70        -0.11
# amazon_low           0.72        -0.11
# amazon_close         0.71        -0.11
# amazon_volume       -0.38         0.24
# google_open          0.63        -0.06
# google_high          0.63        -0.06
# google_low           0.64        -0.07
# google_close         0.63        -0.06
# google_volume       -0.21         0.26
# uber_open            1.00        -0.17
# uber_high            1.00        -0.16
# uber_low             1.00        -0.18
# uber_close           1.00        -0.17
# uber_volume         -0.17         1.00

# %%
df.columns
# Out:
# Index(['apple_open', 'apple_high', 'apple_low', 'apple_close', 'apple_volume',
#        'amazon_open', 'amazon_high', 'amazon_low', 'amazon_close',
#        'amazon_volume', 'google_open', 'google_high', 'google_low',
#        'google_close', 'google_volume', 'uber_open', 'uber_high', 'uber_low',
#        'uber_close', 'uber_volume'],
#       dtype='object')

# %% [markdown]
# metoda '.endswith' określa jak ma się kończyć w tym wypadku nazwa kolumny

# %%
closes = [col for col in df.columns if col.endswith('close')]
closes
# Out:
# ['apple_close', 'amazon_close', 'google_close', 'uber_close']

# %%
df[closes].corr()
# Out:
#               apple_close  amazon_close  google_close  uber_close
# apple_close          1.00          0.52          0.89        0.50
# amazon_close         0.52          1.00          0.69        0.71
# google_close         0.89          0.69          1.00        0.63
# uber_close           0.50          0.71          0.63        1.00

# %% [markdown]
# dodatkowe kolumny kończące się na 'volume'

# %%
closes = [col for col in df.columns if col.endswith('close') or col.endswith('volume')]
closes
# Out:
# ['apple_close',
#  'apple_volume',
#  'amazon_close',
#  'amazon_volume',
#  'google_close',
#  'google_volume',
#  'uber_close',
#  'uber_volume']

# %%
df[closes].corr()
# Out:
#                apple_close  apple_volume  amazon_close  amazon_volume  \
# apple_close           1.00         -0.56          0.52          -0.36
# apple_volume         -0.56          1.00         -0.16           0.62
# amazon_close          0.52         -0.16          1.00          -0.19
# amazon_volume        -0.36          0.62         -0.19           1.00
# google_close          0.89         -0.53          0.69          -0.40
# google_volume        -0.17          0.47         -0.17           0.56
# uber_close            0.50         -0.32          0.71          -0.38
# uber_volume          -0.04          0.22         -0.11           0.24
#
#                google_close  google_volume  uber_close  uber_volume
# apple_close            0.89          -0.17        0.50        -0.04
# apple_volume          -0.53           0.47       -0.32         0.22
# amazon_close           0.69          -0.17        0.71        -0.11
# amazon_volume         -0.40           0.56       -0.38         0.24
# google_close           1.00          -0.23        0.63        -0.06
# google_volume         -0.23           1.00       -0.21         0.26
# uber_close             0.63          -0.21        1.00        -0.17
# uber_volume           -0.06           0.26       -0.17         1.00

# %% [markdown]
# ### <a name='a5'></a> Metoda append()

# %% [markdown]
# metoda append pozwala dorzucać dane do obiektu df

# %%
uber.head()
# Out:
#             uber_open  uber_high  uber_low  uber_close  uber_volume
# Date
# 2024-08-05      55.53      58.65     54.84       58.48     32063685
# 2024-08-02      59.38      59.58     56.86       58.99     27654556
# 2024-08-01      64.86      65.00     60.76       61.02     18967935
# 2024-07-31      63.88      65.18     63.66       64.47     18209679
# 2024-07-30      64.15      64.77     62.61       63.09     16506187

# %%
uber_6 = uber[uber.index.month == 6]
uber_6
# Out:
#             uber_open  uber_high  uber_low  uber_close  uber_volume
# Date
# 2024-06-28      70.81      73.26     70.77       72.68     21375880
# 2024-06-27      70.98      71.32     70.07       70.34      9650481
# 2024-06-26      70.94      71.60     70.55       70.85     10232568
# 2024-06-25      71.86      72.94     70.22       71.38     18911562
# 2024-06-24      69.83      71.23     69.75       70.54     12479277
# ...               ...        ...       ...         ...          ...
# 2020-06-05      37.53      38.78     36.92       37.21     30393429
# 2020-06-04      36.42      37.30     36.28       36.43     17423577
# 2020-06-03      36.20      37.37     36.14       36.75     23051776
# 2020-06-02      36.16      36.42     35.26       35.81     19328415
# 2020-06-01      35.64      36.39     35.16       35.82     21893806
#
# [105 rows x 5 columns]

# %%
uber_7 = uber[uber.index.month == 7]
uber_7
# Out:
#             uber_open  uber_high  uber_low  uber_close  uber_volume
# Date
# 2024-07-31      63.88      65.18     63.66       64.47     18209679
# 2024-07-30      64.15      64.77     62.61       63.09     16506187
# 2024-07-29      64.83      65.26     63.72       63.76     16906996
# 2024-07-26      66.10      66.26     64.18       64.40     17379446
# 2024-07-25      66.00      69.37     64.40       65.74     22596919
# ...               ...        ...       ...         ...          ...
# 2020-07-08      33.21      33.97     32.68       33.93     24602369
# 2020-07-07      32.46      33.56     32.39       32.82     34874658
# 2020-07-06      33.10      33.20     31.76       32.52     42392222
# 2020-07-02      31.02      31.57     30.51       30.68     14981137
# 2020-07-01      30.96      31.27     30.16       30.43     13611544
#
# [105 rows x 5 columns]

# %% [markdown]
# Hipoteza
#
# Komunikat o błędzie "AttributeError: 'DataFrame' object has no attribute 'append'" wskazuje, że próbujesz użyć metody .append() na obiekcie DataFrame z biblioteki Pandas, co nie jest obsługiwane w ten sam sposób, jak w przypadku list.
# Metoda .append() dla obiektów DataFrame została uznana za przestarzałą i później usunięta, ponieważ zwracała nowy obiekt DataFrame zamiast modyfikować oryginalny. To zachowanie często prowadziło do zamieszania i nieoczekiwanych rezultatów.
# Sugerowane zmiany
#
#
#
#   import pandas as pd  # Zaimportuj pandas, jeśli jeszcze nie zostało to zrobione
#
# uber_6_7 = pd.concat([uber_6, uber_7])  # Użyj pd.concat do połączenia obiektów DataFrame
# uber_6_7
# Use code with caution
# Wyjaśnienie:
# Zamiast używać .append(), użyj funkcji pd.concat() z biblioteki Pandas. Ta funkcja pozwala na połączenie dwóch lub więcej obiektów DataFrame wzdłuż określonej osi (zwykle wierszy). Przekazując listę obiektów DataFrame [uber_6, uber_7] do pd.concat(), tworzysz nowy obiekt DataFrame uber_6_7, który zawiera połączone wiersze zarówno uber_6, jak i uber_7.

# %%
import pandas as pd  # Zaimportuj pandas, jeśli jeszcze nie zostało to zrobione

uber_6_7 = pd.concat([uber_6, uber_7])  # Użyj pd.concat do połączenia obiektów DataFrame
uber_6_7
# Out:
#             uber_open  uber_high  uber_low  uber_close  uber_volume
# Date
# 2024-06-28      70.81      73.26     70.77       72.68     21375880
# 2024-06-27      70.98      71.32     70.07       70.34      9650481
# 2024-06-26      70.94      71.60     70.55       70.85     10232568
# 2024-06-25      71.86      72.94     70.22       71.38     18911562
# 2024-06-24      69.83      71.23     69.75       70.54     12479277
# ...               ...        ...       ...         ...          ...
# 2020-07-08      33.21      33.97     32.68       33.93     24602369
# 2020-07-07      32.46      33.56     32.39       32.82     34874658
# 2020-07-06      33.10      33.20     31.76       32.52     42392222
# 2020-07-02      31.02      31.57     30.51       30.68     14981137
# 2020-07-01      30.96      31.27     30.16       30.43     13611544
#
# [210 rows x 5 columns]
